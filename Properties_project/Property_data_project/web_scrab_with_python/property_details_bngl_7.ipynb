# %%
import urllib.request
import re
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
api_url='https://api.scrapingdog.com/scrape?api_key=6482e8f843c55505c48bddb2&url=https://www.magicbricks.com/new-projects-Bangalore/page-7'

# %%
page=requests.get(api_url)
page.content
# Out:
# b'<!DOCTYPE html><html><head>\n  \t<!-- google tag manager include -->\n\t<!-- Google Tag Manager -->\n<script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-N7Q8HKZ&amp;l=MB_GTM_dataLayer"></script><script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WQW25Z"></script><script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-WQW25Z\');</script>\n<!-- End Google Tag Manager -->\n\n<!-- Google Tag Manager -->\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager
# ...

# %%
soup=BeautifulSoup(page.content,'html.parser')
project_name_content=soup.find_all(class_='proHeading')
project_name_content=str(project_name_content)
project_name_content
# Out:
# '[<p class="proHeading">\n<strong>North Woods</strong>\n</p>, <p class="proHeading">\n<strong>Adarsh Tropica</strong>\n</p>, <p class="proHeading">\n<strong>Casagrand Meridian</strong>\n</p>, <p class="proHeading">\n<strong>SNN Raj Bay Vista</strong>\n</p>, <p class="proHeading">\n<strong>Ma Sarada Upavan</strong>\n</p>, <p class="proHeading">\n<strong>Govianu Sangam</strong>\n</p>, <p class="proHeading">\n<strong>Happy Village</strong>\n</p>, <p class="proHeading">\n<strong>Purva Zenium 2</strong>\n</p>, <p class="proHeading">\n<strong>GM Govianu</strong>\n</p>, <p class="proHeading">\n<strong>Puravankara Purva Meraki</strong>\n</p>, <p class="proHeading">\n<strong>SNN Raj Viviente</strong>\n</p>, <p class="proHeading">\n<strong>Bhavisha Bentley Goldberg Phase II</strong>\n</p>, <p class="proHeading">\n<strong>Sowparnika Olivia Nest</strong>\n</p>, <p class="proHeading">\n<strong>DSR Green Waters</strong>\n</p>, <p class="proHeading">\n<strong>Vijaya Luxo</strong>\n</p>, <p class="p
# ...

# %%
re_project_name=r'>(.*?)<\/strong>'
Project_name=re.findall(re_project_name,project_name_content)
Project_name
# Out:
# ['North Woods',
#  'Adarsh Tropica',
#  'Casagrand Meridian',
#  'SNN Raj Bay Vista',
#  'Ma Sarada Upavan',
#  'Govianu Sangam',
#  'Happy Village',
#  'Purva Zenium 2',
#  'GM Govianu',
#  'Puravankara Purva Meraki',
#  'SNN Raj Viviente',
#  'Bhavisha Bentley Goldberg Phase II',
#  'Sowparnika Olivia Nest',
#  'DSR Green Waters',
#  'Vijaya Luxo',
#  'Brigade Oasis',
#  'Arvind Greatlands']

# %%
project_Area_pune_content=soup.find_all(class_='proGroup')
project_Area_pune_content=str(project_Area_pune_content)
project_Area_pune_content
# Out:
# '[<p class="proGroup">\n<!-- Jira SA1-19400 implementation start -->\n\t\t              \t\n\t\t              \t\n\t\t              \t\n\t\t              \t\n\t\t              \t\n\t\t                  \tin  <a href="https://www.magicbricks.com/Chikkaballapur-in-Bangalore-Overview#" target="_blank">Chikkaballapur</a>\n\t\t                  \t,  Bangalore\n\t\t                  \n\t\t                  <!-- Jira SA1-19400 implementation end -->\n</p>, <p class="proGroup projDeveloper">\n<label>by</label> <span>Living Structures</span>\n</p>, <p class="proGroup">\n<!-- Jira SA1-19400 implementation start -->\n\t\t              \t\n\t\t              \t\n\t\t              \t\n\t\t              \t\n\t\t              \t\n\t\t                  \tin  <a href="https://www.magicbricks.com/Choodasandra-in-Bangalore-Overview#" target="_blank">Choodasandra</a>\n\t\t                  \t,  Bangalore\n\t\t                  \n\t\t                  <!-- Jira SA1-19400 implementation end -->\n</p>, <p c
# ...

# %%
re_project_Area_pune=r'>(.*?)<\/a>'
Project_Area_pune=re.findall(re_project_Area_pune,project_Area_pune_content)
Project_Area_pune
# Out:
# ['Chikkaballapur',
#  'Choodasandra',
#  'Bhattarahalli',
#  'Kodichikkanahalli Main Road',
#  'Bommasandra',
#  'Yelahanka',
#  'Sarjapur Road',
#  'Kempegowda International Airport Road',
#  'Seshadripuram',
#  'Hsr Layout',
#  'Bannerghatta Main Road',
#  'Sarjapur Road',
#  'Anekal',
#  'Varthur',
#  'RR Nagar',
#  'Devanahalli',
#  'Devanahalli']

# %%
project_developer_content=soup.find_all(class_='proGroup projDeveloper')
project_developer_content=str(project_developer_content)
project_developer_content
# Out:
# '[<p class="proGroup projDeveloper">\n<label>by</label> <span>Living Structures</span>\n</p>, <p class="proGroup projDeveloper">\n<label>by</label> <span>Adarsh Group</span>\n</p>, <p class="proGroup projDeveloper">\n<label>by</label> <span>Casagrand Builder Pvt. Ltd.</span>\n</p>, <p class="proGroup projDeveloper">\n<label>by</label> <span>SNN Arjun Builders LLP</span>\n</p>, <p class="proGroup projDeveloper">\n<label>by</label> <span>Ma Sarada Constructions</span>\n</p>, <p class="proGroup projDeveloper">\n<label>by</label> <span>Govianu Wealth Management Pvt Ltd</span>\n</p>, <p class="proGroup projDeveloper">\n<label>by</label> <span>Cleartitle Properties</span>\n</p>, <p class="proGroup projDeveloper">\n<label>by</label> <span>Puravankara Ltd.</span>\n</p>, <p class="proGroup projDeveloper">\n<label>by</label> <span>Govianu Wealth Management Pvt Ltd</span>\n</p>, <p class="proGroup projDeveloper">\n<label>by</label> <span>Puravankara Ltd.</span>\n</p>, <p class="proGroup projDev
# ...

# %%
re_project_developer=r'by</label> <span>(.*?)<\/span>'
Project_developer=re.findall(re_project_developer,project_developer_content)
Project_developer
# Out:
# ['Living Structures',
#  'Adarsh Group',
#  'Casagrand Builder Pvt. Ltd.',
#  'SNN Arjun Builders LLP',
#  'Ma Sarada Constructions',
#  'Govianu Wealth Management Pvt Ltd',
#  'Cleartitle Properties',
#  'Puravankara Ltd.',
#  'Govianu Wealth Management Pvt Ltd',
#  'Puravankara Ltd.',
#  'SNN Raj Corp',
#  'Bhavisha Properties',
#  'Sowparnika Projects &amp; Infrastructure Pvt. Ltd.',
#  'DSR Group',
#  'Vijaya Enterprises',
#  'Brigade Enterprises Ltd.',
#  'Arvind Homes Pvt. Ltd.']

# %%
project_possesion_content=soup.find_all(class_='proDetailsRowElm posByCons')
project_possesion_content=str(project_possesion_content)
project_possesion_content
# Out:
# '[<div class="proDetailsRowElm posByCons">\n\t               \t\t\n\t\t\t\t\t\t \tPossession in 2023\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t               \t</div>, <div class="proDetailsRowElm posByCons">\n\t               \t\t\n\t\t\t\t\t\t \tPossession in 2027\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t               \t</div>, <div class="proDetailsRowElm posByCons">\n\t               \t\t\n\t\t\t\t\t\t \tPossession in 2024\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t               \t</div>, <div class="proDetailsRowElm posByCons">\n\t               \t\t\n\t\t\t\t\t\t \tPossession in 2028\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t               \t</div>, <div class="proDetailsRowElm posByCons">\n\t               \t\t\n\t\t\t\t\t\t \tPossession in 2024\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t               \t</div>, <div class="proDetailsRowElm posByCons">\n\t               \t\t\n\t\t\t\t\t\t \tPossession in 2023\n\t\t\t\t\t\t\n\t\t\t\t\t\t\n\t               \t</div>, <div class="proDetailsRowElm posByCons">\n\t               \t\t\n\
# ...

# %%
re_project_possesion=r'\b(\w+\s+\w+\s+\d{4})\b'
Project_possesion=re.findall(re_project_possesion,project_possesion_content)
Project_possesion
# Out:
# ['Possession in 2023',
#  'Possession in 2027',
#  'Possession in 2024',
#  'Possession in 2028',
#  'Possession in 2024',
#  'Possession in 2023',
#  'Possession in 2027',
#  'Possession in 2025',
#  'Possession in 2027',
#  'Possession in 2024',
#  'Possession in 2024',
#  'Possession in 2027',
#  'Possession in 2025',
#  'Possession in 2024',
#  'Possession in 2025',
#  'Possession in 2026']

# %%
project_2bhk_price_content=soup.find_all(class_='proDescColm3')
project_2bhk_price_content=str(project_2bhk_price_content)
project_2bhk_price_content
# Out:
# '[<div class="proDescColm3" id="priceVal1068803" style="display:none">\n\t\t\t\t\t              \t\n\t\t\t\t\t                \t\n\t\t\t\t\t                    \t\n\t\t\t\t\t                        \n\t\t\t\t\t                        \t18 Lac - 84 Lac\n\t\t\t\t\t                        \n\t\t\t\t\t                   \t\n\t\t\t\t\t\t\t\t\t    \n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t              </div>, <div class="proDescColm3" id="price1068803">\n<span class="budRsIcon"></span> 18 Lac - 84 Lac\n\t\t\t\t\t                        \n\t\t\t\t\t                   \t\n\t\t\t\t\t\t\t\t\t    \n\t\t\t\t\t\t\t\t\t\n\t\t\t\t\t              </div>, <div class="proDescColm3" id="priceVal1008003" style="display:none">\n\t\t\t\t\t              \t\n\t\t\t\t\t                \t\n\t\t\t\t\t                    \t\n\t\t\t\t\t                        \n\t\t\t\t\t                        \t64 Lac - 69 Lac\n\t\t\t\t\t                        \n\t\t\t\t\t                   \t\n\t\t\t\t\t\t\t\t\t    \n\t\t\t\t\t\t\t\t
# ...

# %%
cleaned_text = re.sub(r'[\n\t]+', '', project_2bhk_price_content)
cleaned_text
# Out:
# '[<div class="proDescColm3" id="priceVal1068803" style="display:none">                                                                                                  18 Lac - 84 Lac                                                             </div>, <div class="proDescColm3" id="price1068803"><span class="budRsIcon"></span> 18 Lac - 84 Lac                                                             </div>, <div class="proDescColm3" id="priceVal1008003" style="display:none">                                                                                                  64 Lac - 69 Lac                                                             </div>, <div class="proDescColm3" id="price1008003"><span class="budRsIcon"></span> 64 Lac - 69 Lac                                                             </div>, <div class="proDescColm3" id="priceVal1005863" style="display:none">                                                                                                  80 Lac - 9
# ...

# %%
re_project_2bhk_pricer=r'<\/span>(.*?)<\/div>'

Project_2bhk_price=re.findall(re_project_2bhk_pricer,cleaned_text)
Project_2bhk_price
# Out:
# [' 18 Lac - 84 Lac                                                             ',
#  ' 64 Lac - 69 Lac                                                             ',
#  ' 80 Lac - 94 Lac                                                             ',
#  ' 95 Lac - 1.45 Cr                                                             ',
#  ' 1.17 Cr - 1.26 Cr                                                             ',
#  ' 87 Lac - 1.18 Cr                                                             ',
#  ' 1.03 Cr - 1.71 Cr                                                             ',
#  ' 1.76 Cr                                                             ',
#  ' 3 Cr - 3.05 Cr                                                             ',
#  ' 3.50 Cr                                                             ',
#  ' 3.83 Cr - 3.84 Cr                                                             ',
# ...

# %%
project_carpet_area_content=soup.find_all(class_='proDescColm2')
project_carpet_area_content=str(project_carpet_area_content)
project_carpet_area_content
# Out:
# '[<div class="proDescColm2" id="propertyArea1068803">\n\t\t\t\t\t              \t\n\t\t\t\t\t                \t720 - 3360 sqft\n\t\t\t\t\t                \n\t\t\t\t\t                \n\t\t\t\t\t                \n\t\t\t\t\t                \n\t\t\t\t\t              </div>, <div class="proDescColm2" id="propertyArea1008003">\n\t\t\t\t\t              \t\n\t\t\t\t\t                \t640 - 980 sqft\n\t\t\t\t\t                \n\t\t\t\t\t                \n\t\t\t\t\t                \n\t\t\t\t\t                \t<span>(Carpet Area)</span>\n</div>, <div class="proDescColm2" id="propertyArea1005863">\n\t\t\t\t\t              \t\n\t\t\t\t\t                \t976  sqft\n\t\t\t\t\t                \n\t\t\t\t\t                \n\t\t\t\t\t                \n\t\t\t\t\t                \t<span>(Carpet Area)</span>\n</div>, <div class="proDescColm2" id="propertyArea1005871">\n\t\t\t\t\t              \t\n\t\t\t\t\t                \t1200 - 2045 sqft\n\t\t\t\t\t                \n\t\t\t\t\t                \n\t
# ...

# %%
clean=re.sub(r'[\n\t]+','',project_carpet_area_content)
clean
# Out:
# '[<div class="proDescColm2" id="propertyArea1068803">                              720 - 3360 sqft                                                                              </div>, <div class="proDescColm2" id="propertyArea1008003">                              640 - 980 sqft                                                                <span>(Carpet Area)</span></div>, <div class="proDescColm2" id="propertyArea1005863">                              976  sqft                                                                <span>(Carpet Area)</span></div>, <div class="proDescColm2" id="propertyArea1005871">                              1200 - 2045 sqft                                                                <span>(Carpet Area)</span></div>, <div class="proDescColm2" id="propertyArea1085923">                              788 - 805 sqft                                                                <span>(Carpet Area)</span></div>, <div class="proDescColm2" id="propertyArea105
# ...

# %%
re_carpet_area=r'>(.*?)<\/div>'
project_carpet_area=re.findall(re_carpet_area,clean)
project_carpet_area
# Out:
# ['                              720 - 3360 sqft                                                                              ',
#  '                              640 - 980 sqft                                                                <span>(Carpet Area)</span>',
#  '                              976  sqft                                                                <span>(Carpet Area)</span>',
#  '                              1200 - 2045 sqft                                                                <span>(Carpet Area)</span>',
#  '                              788 - 805 sqft                                                                <span>(Carpet Area)</span>',
#  '                              1034 - 1272 sqft                                                                              ',
#  '                              1242 - 1763 sqft                                                                              ',
# ...

# %%
re_carpet_area=r'\d+(?:\s*-\s*\d+)?\s*sqft'
carpet_area=re.findall(re_carpet_area,str(project_carpet_area))
carpet_area
# Out:
# ['720 - 3360 sqft',
#  '640 - 980 sqft',
#  '976  sqft',
#  '1200 - 2045 sqft',
#  '788 - 805 sqft',
#  '1034 - 1272 sqft',
#  '1242 - 1763 sqft',
#  '2123  sqft',
#  '2000 - 2025 sqft',
#  '2500  sqft',
#  '2762 - 2770 sqft',
#  '3745 - 3746 sqft',
#  '3891 - 3893 sqft',
#  '1032 - 1068 sqft',
#  '1248 - 1338 sqft',
#  '750  sqft',
#  '766 - 7881 sqft',
#  '959 - 1087 sqft',
#  '1265  sqft',
#  '1525  sqft']

# %%
df_carpet_price=pd.DataFrame(list(zip(Project_2bhk_price,carpet_area)))
df_carpet_price

Carpet_Price=df_carpet_price.rename(columns={0:'Price_2_3BHK',1:'Carpet_2_3BHK'})
Carpet_Price
# Out:
#                                          Price_2_3BHK     Carpet_2_3BHK
# 0    18 Lac - 84 Lac                              ...   720 - 3360 sqft
# 1    64 Lac - 69 Lac                              ...    640 - 980 sqft
# 2    80 Lac - 94 Lac                              ...         976  sqft
# 3    95 Lac - 1.45 Cr                             ...  1200 - 2045 sqft
# 4    1.17 Cr - 1.26 Cr                            ...    788 - 805 sqft
# 5    87 Lac - 1.18 Cr                             ...  1034 - 1272 sqft
# 6    1.03 Cr - 1.71 Cr                            ...  1242 - 1763 sqft
# 7    1.76 Cr                                      ...        2123  sqft
# 8    3 Cr - 3.05 Cr                               ...  2000 - 2025 sqft
# 9    3.50 Cr                                      ...        2500  sqft
# 10   3.83 Cr - 3.84 Cr                            ...  2762 - 2770 sqft
# 11   5.20 Cr - 5.21 Cr                            ...  3745 - 3746 sqft
# ...

# %%
Carpet_Price['3BHK_Price']=''
Carpet_Price['3BHK_Carpet']=''
Carpet_Price
# Out:
#                                          Price_2_3BHK     Carpet_2_3BHK  \
# 0    18 Lac - 84 Lac                              ...   720 - 3360 sqft
# 1    64 Lac - 69 Lac                              ...    640 - 980 sqft
# 2    80 Lac - 94 Lac                              ...         976  sqft
# 3    95 Lac - 1.45 Cr                             ...  1200 - 2045 sqft
# 4    1.17 Cr - 1.26 Cr                            ...    788 - 805 sqft
# 5    87 Lac - 1.18 Cr                             ...  1034 - 1272 sqft
# 6    1.03 Cr - 1.71 Cr                            ...  1242 - 1763 sqft
# 7    1.76 Cr                                      ...        2123  sqft
# 8    3 Cr - 3.05 Cr                               ...  2000 - 2025 sqft
# 9    3.50 Cr                                      ...        2500  sqft
# 10   3.83 Cr - 3.84 Cr                            ...  2762 - 2770 sqft
# 11   5.20 Cr - 5.21 Cr                            ...  3745 - 3746 sqft
# ...

# %%
New_Carpet_Price=pd.DataFrame({'Price_2_3BHK':Carpet_Price['Price_2_3BHK'].iloc[::2].values,
                               '3BHK_Price':Carpet_Price['Price_2_3BHK'].iloc[1::2].values,
                               'Carpet_2_3BHK':Carpet_Price['Carpet_2_3BHK'].iloc[1::2].values,
                               '3BHK_Carpet':Carpet_Price['Carpet_2_3BHK'].iloc[::2].values})
New_Carpet_Price
# Out:
#                                         Price_2_3BHK  \
# 0   18 Lac - 84 Lac                              ...
# 1   80 Lac - 94 Lac                              ...
# 2   1.17 Cr - 1.26 Cr                            ...
# 3   1.03 Cr - 1.71 Cr                            ...
# 4   3 Cr - 3.05 Cr                               ...
# 5   3.83 Cr - 3.84 Cr                            ...
# 6   4.08 Cr - 4.25 Cr                            ...
# 7   75 Lac - 81 Lac                              ...
# 8   78.8 Lac - 90.7 Lac                          ...
# 9   75 Lac                                       ...
#
#                                           3BHK_Price     Carpet_2_3BHK  \
# 0   64 Lac - 69 Lac                              ...    640 - 980 sqft
# 1   95 Lac - 1.45 Cr                             ...  1200 - 2045 sqft
# 2   87 Lac - 1.18 Cr                             ...  1034 - 1272 sqft
# 3   1.76 Cr                                      ...        2123  sqft
# ...

# %%
Carpet_Price_Rename=New_Carpet_Price.rename(columns={'Price_2_3BHK':'2BHK_Price','Carpet_2_3BHK':'3BHK_Carpet','3BHK_Carpet':'2BHK_Carpet'})
Carpet_Price_Rename
# Out:
#                                           2BHK_Price  \
# 0   18 Lac - 84 Lac                              ...
# 1   80 Lac - 94 Lac                              ...
# 2   1.17 Cr - 1.26 Cr                            ...
# 3   1.03 Cr - 1.71 Cr                            ...
# 4   3 Cr - 3.05 Cr                               ...
# 5   3.83 Cr - 3.84 Cr                            ...
# 6   4.08 Cr - 4.25 Cr                            ...
# 7   75 Lac - 81 Lac                              ...
# 8   78.8 Lac - 90.7 Lac                          ...
# 9   75 Lac                                       ...
#
#                                           3BHK_Price       3BHK_Carpet  \
# 0   64 Lac - 69 Lac                              ...    640 - 980 sqft
# 1   95 Lac - 1.45 Cr                             ...  1200 - 2045 sqft
# 2   87 Lac - 1.18 Cr                             ...  1034 - 1272 sqft
# 3   1.76 Cr                                      ...        2123  sqft
# ...

# %%
df_Properties_Details=pd.DataFrame(list(zip(Project_name,Project_Area_pune,Project_developer,Project_possesion)))

# %%
Properties_Details=df_Properties_Details.rename(columns={0:'Project_name',1:'Area_pune',2:'Developer',3:'Possesion_Details'})
Properties_Details
# Out:
#                           Project_name                              Area_pune  \
# 0                          North Woods                         Chikkaballapur
# 1                       Adarsh Tropica                           Choodasandra
# 2                   Casagrand Meridian                          Bhattarahalli
# 3                    SNN Raj Bay Vista            Kodichikkanahalli Main Road
# 4                     Ma Sarada Upavan                            Bommasandra
# 5                       Govianu Sangam                              Yelahanka
# 6                        Happy Village                          Sarjapur Road
# 7                       Purva Zenium 2  Kempegowda International Airport Road
# 8                           GM Govianu                          Seshadripuram
# 9             Puravankara Purva Meraki                             Hsr Layout
# 10                    SNN Raj Viviente                 Bannerghatta Main Road
# ...

# %%
Properties_Details=df_Properties_Details.rename(columns={0:'Project_name',1:'Area_pune',2:'Developer',3:'Possesion_Details'})
Properties_Details
# Out:
#                           Project_name                              Area_pune  \
# 0                          North Woods                         Chikkaballapur
# 1                       Adarsh Tropica                           Choodasandra
# 2                   Casagrand Meridian                          Bhattarahalli
# 3                    SNN Raj Bay Vista            Kodichikkanahalli Main Road
# 4                     Ma Sarada Upavan                            Bommasandra
# 5                       Govianu Sangam                              Yelahanka
# 6                        Happy Village                          Sarjapur Road
# 7                       Purva Zenium 2  Kempegowda International Airport Road
# 8                           GM Govianu                          Seshadripuram
# 9             Puravankara Purva Meraki                             Hsr Layout
# 10                    SNN Raj Viviente                 Bannerghatta Main Road
# ...

# %%
Properties_1=pd.concat([Properties_Details,Carpet_Price_Rename],axis=1)
Properties_1
# Out:
#                           Project_name                              Area_pune  \
# 0                          North Woods                         Chikkaballapur
# 1                       Adarsh Tropica                           Choodasandra
# 2                   Casagrand Meridian                          Bhattarahalli
# 3                    SNN Raj Bay Vista            Kodichikkanahalli Main Road
# 4                     Ma Sarada Upavan                            Bommasandra
# 5                       Govianu Sangam                              Yelahanka
# 6                        Happy Village                          Sarjapur Road
# 7                       Purva Zenium 2  Kempegowda International Airport Road
# 8                           GM Govianu                          Seshadripuram
# 9             Puravankara Purva Meraki                             Hsr Layout
# 10                    SNN Raj Viviente                 Bannerghatta Main Road
# ...
